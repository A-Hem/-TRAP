# %% [markdown]
# <a href="https://colab.research.google.com/github/A-Hem/-TRAP/blob/codespace-zany-memory-g44p7jjgwvx7395j9/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import random

def create_triplet_list(data_directory):
    """
    Scans the data directory and creates a list of (Anchor, Positive, Negative) file paths.
    """
    triplets = []
    # Your logic to scan folders, identify images from the same camera (positives)
    # and different cameras (negatives) would go here.

    # Example logic:
    # for each image (anchor):
    #   find another image from the same camera (positive)
    #   find an image from a different camera (negative)
    #   triplets.append((anchor_path, positive_path, negative_path))

    print(f"Generated {len(triplets)} triplets.")
    return triplets
